# %%
name = "karan"

# %%
name #print
# Out:
# 'karan'

# %%
name.upper()
# Out:
# 'KARAN'

# %%
name.endswith("heer")
# Out:
# False

# %%
name.endswith("an")
# Out:
# True

# %%
str = "karanbyte"

# %%
print(len(str)) #prints the length of string
# Out:
# 9

# %%
str[0:4] #gives character between given num
# Out:
# 'kara'

# %%
text = "learning a data science"

# %% [markdown]
# text.split() #Splits string into a list

# %% [markdown]
# string formatting (f-strings)

# %%
name = "karan"

# %%
year = 2025

# %%
f"hello {name}, started ds in {year}"
# Out:
# 'hello karan, started ds in 2025'
