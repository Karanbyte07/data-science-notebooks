# %%
# Empty list
my_list = []

# List with elements
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed_list = [1, "Hello", 3.14, True]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)  # ['apple', 'banana', 'cherry', 'orange']

fruits.sort()
print(fruits)  # ['apple', 'banana', 'cherry', 'orange']

# %%
list1 = [5,2,5,8,4,89]

# %%
list1 #print the list
# Out:
# [5, 2, 5, 8, 4, 89]

# %%
list1.sort()

# %%
list1 #sort the list in ascending
# Out:
# [2, 4, 5, 5, 8, 89]

# %%
l2 = [78,True, False, [89,45]] #nested list and indexing starts from "0"

# %%
l2
# Out:
# [78, True, False, [89, 45]]

# %%
l2[1]
# Out:
# True

# %%
list1 + l2 #concatenate the list
# Out:
# [2, 4, 5, 5, 8, 89, 78, True, False, [89, 45]]

# %%
if 78 in l2:
    print("yes")
# Out:
# yes

# %%
78 in l2 #boolean return
# Out:
# True

# %%
s = "jack-karan-supriya-dev-john" #splitting a string into a list

# %%
s.split("-")
# Out:
# ['jack', 'karan', 'supriya', 'dev', 'john']
