# %% [markdown]
# ## Taking Input from the user

# %%
a = input("type your name")
# Out:
# type your name karanjeet

# %%
b = input("enter the value of b") #by default it takes input as a string
# Out:
# enter the value of b 5

# %%
c = input("enter the value of c= ")
# Out:
# enter the value of c=  4

# %%
b+c #concatenate bcoz it is string
# Out:
# '54'

# %%
int(b) + int(c) #typecasting to int
# Out:
# 9
