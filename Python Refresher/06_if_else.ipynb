# %%
a = 40

# %%
b = 30

# %%
if(a>b):
    print("a is greater")
else:
    print("b is greater")
# Out:
# b is greater

# %% [markdown]
# ## Functions declaration

# %%
def avg(a,b):
    return (a+b)/2

# %%
avg(6,4)
# Out:
# 5.0

# %%
def sum(num1, num2):
    return (num1+ num2)

# %%
sum(1,2)
# Out:
# 3

# %%
age = 80
if age < 18:
    print("baccha h ji")
elif age < 65:
    print("adult")
else :
    print("senior citizen")
# Out:
# senior citizen
