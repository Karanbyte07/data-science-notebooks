# %%
a = 5 #initialization

# %%
b = 8

# %%
a+b
# Out:
# 13

# %%
str ="karan"

# %%
print(type(str))
# Out:
# <class 'str'>

# %% [markdown]
# You don't need to declare variable type

# %%
num1 = "45466"

# %%
num2 = "8898"

# %%
num1+num2
# Out:
# '454668898'

# %%
int(num1) + int(num2) # to add both and this is typecasting
# Out:
# 54364
