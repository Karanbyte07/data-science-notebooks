# %%
import json

# %%
# Open the text file containing raw Instagram-like data
# utf-8 encoding is used to avoid errors with special characters
with open("initialdata.txt" , encoding = 'utf-8') as file:
    data = file.read()

print(data)
# Out:
# intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio
#
# _anujsinghal
# 1,785 posts
# 681K followers
# 248 following
# Anuj Singhal
# Digital creator
# Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India
# Let’s talk about finance and life
# Contact: Singhalanuj1010@gmail.com
# hindi.cnbctv18.com/market-gurukul
#
# code_flare
# 165 posts
# 216 followers
# 10 following
# The Journey Notebook | Travel | Food Blogger
# Blogger
# 📍 Exploring places & phases of life 🌍
# .
# 🍵 From chai breaks to flight takes ✈️
# .
# 💫 Travel | Food | Daily life 🌸
# youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a
#
# bangalore_tech_bro
# 402 posts
# 12.5K followers
# 890 following
# Rahul | HSR Hustler
# Entrepreneur
# 🚀 Building the next Unicorn in Fintech
# ☕ 3rd Wave Coffee addict
# 💻 Python | React | AI
# 📍 HSR Layout, BLR
# linktr.ee/rahulbuilds
#
# silkboard_survivor
# 55 posts
# 1,200 followers
# 50 following
# Priya D.
# Public Figure
# 🚦 Stuck in traffic since 2019
# 🌧️ Loving the Bangalore weather, hating the cabs
# 🐍 Data Scientist by day, meme maker by night
# 📍 ORR
# bit.ly/my-traffic-rants
#
# startuphub_blr
# 2,300 posts
# 45K followers
# 120 following
# Startup Hub Bangalore
# Media
# 🦄 News from the Silicon Valley of India
# 📢 Funding alerts, Hiring trends, and Drama
# 📩 DM for features
# startuphub.blr/newsletter
#
# foodie_in_kora
# 890 posts
# 5,600 followers
# 400 following
# Sneha | Bangalore Eats
# Food & Drink
# Aagrah to Truffles 🍔
# Exploring Koramangala's cafe culture ☕
# DM for collabs
# https://www.google.com/search?q=zomato.com/users/sneha123
#
# venture_vikram
# 120 posts
# 30K followers
# 500 following
# Vikram | Angel Investor
# Investor
# 💸 Helping founders go 0 to 1
# Ex-Google, Ex-Amazon
# Investing in DeepTech & AI
# 📍 Indiranagar
# vikram.vc/pitch-deck
#
# python_meetup_blr
# 60 posts
# 3,400 followers
# 10 following
# PyBangalore Community
# Community
# 🐍 Weekly meetups for Pythonistas
# 📍 Cubbon Park | Sundays 4 PM
# Coding + Coffee + Community
# https://www.google.com/search?q=meetup.com/pybangalore
#
# indiranagar_gossip
# 300 posts
# 8,900 followers
# 20 following
# Indiranagar Spy
# Personal Blog
# Not just about 100ft Road 🤫
# Spilling tea on the best brunches and worst landlords
# Bengaluru
# https://www.google.com/search?q=medium.com/%40indiranagarspy
#
#
# ig_arbin07
# 50 posts
# 33 followers
# 30 following
# aarbinnn
# Gamer
# @dumb.arbin
# 🎮: Banana『juice (IGL🥷)
# Gamer never die, they just respawn🙂‍↔️
#
#
#
# 7iiuliiu
# 1 post
# 44 followers
# 166 following
# ︎𝐄︎ ♡︎.
#
#
# katiasales2220
# 107 posts
# 219 followers
# 1,401 following
# Katia Sales
# Alfabetização e Reforço Escolar
# Ensino Fundamental I e II
# Preparação para Escola Militar
# Português e Matemática
# Cursando Psicopedagogia Estácio

# %%
# Split data into chunks using double newline as separator
# Each chunk represents one profile
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3] # Remove very small or empty chunks
#print(chunks) # All cleaned chunks

# %%
chunks[3] # View 4th profile data (index starts from 0)
# Out:
# 'bangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'

# %%
# Function to parse one chunk (one profile)
def parse_chunk(chunk):
    chunk = chunk.strip() # Remove extra spaces/newlines
    sep_chunk = chunk.split("\n") # Split chunk into individual lines

    # Assign values based on fixed line positions
    username = sep_chunk[0]
    no_of_posts = sep_chunk[1]
    no_of_followers = sep_chunk[2]
    no_of_following = sep_chunk[3]
    name = sep_chunk[4]

    # If type of page and bio exist
    if(len(sep_chunk)> 5): #agar kisi me type of page aur bio na likha ho toh
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:]) # Bio can be multi-line
    else:
            type_of_page = "Unknown" # If type or bio is missing
            bio = ""

    #print(username, no_of_posts, no_of_followers,no_of_following,name, type_of_page, bio, sep = "\n")
   # Return extracted data as dictionary
    return {
        "Username": username,
        "No_of_posts": no_of_posts,
        "No_of_followers": no_of_followers,
        "No_of_following": no_of_following,
        "Name": name,
        "Type_of_page": type_of_page,
        "Bio": bio
    }


#parse_chunk(chunks[3]) # Test function on a single chunk

# %%
# Parse all chunks and store in a list
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks) # Check final parsed data
# Out:
# [{'Username': 'intaglobal', 'No_of_posts': '1,946 posts', 'No_of_followers': '6,851 followers', 'No_of_following': '262 following', 'Name': 'INTA', 'Type_of_page': 'Nonprofit organization', 'Bio': 'The association of ™ professionals.\ninta.campsite.bio'}, {'Username': '_anujsinghal', 'No_of_posts': '1,785 posts', 'No_of_followers': '681K followers', 'No_of_following': '248 following', 'Name': 'Anuj Singhal', 'Type_of_page': 'Digital creator', 'Bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}, {'Username': 'code_flare', 'No_of_posts': '165 posts', 'No_of_followers': '216 followers', 'No_of_following': '10 following', 'Name': 'The Journey Notebook | Travel | Food Blogger', 'Type_of_page': 'Blogger', 'Bio': '📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'Username': 'bangalore_tech_bro', 'No_of_posts': '402 posts', 'No_of_followers': '12.5K followers', 'No_of_following': '890 following', 'Name': 'Rahul | HSR Hustler', 'Type_of_page': 'Entrepreneur', 'Bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}, {'Username': 'silkboard_survivor', 'No_of_posts': '55 posts', 'No_of_followers': '1,200 followers', 'No_of_following': '50 following', 'Name': 'Priya D.', 'Type_of_page': 'Public Figure', 'Bio': '🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'}, {'Username': 'startuphub_blr', 'No_of_posts': '2,300 posts', 'No_of_followers': '45K followers', 'No_of_following': '120 following', 'Name': 'Startup Hub Bangalore', 'Type_of_page': 'Media', 'Bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}, {'Username': 'foodie_in_kora', 'No_of_posts': '890 posts', 'No_of_followers': '5,600 followers', 'No_of_following': '400 following', 'Name': 'Sneha | Bangalore Eats', 'Type_of_page': 'Food & Drink', 'Bio': "Aagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"}, {'Username': 'venture_vikram', 'No_of_posts': '120 posts', 'No_of_followers': '30K followers', 'No_of_following': '500 following', 'Name': 'Vikram | Angel Investor', 'Type_of_page': 'Investor', 'Bio': '💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck'}, {'Username': 'python_meetup_blr', 'No_of_posts': '60 posts', 'No_of_followers': '3,400 followers', 'No_of_following': '10 following', 'Name': 'PyBangalore Community', 'Type_of_page': 'Community', 'Bio': '🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore'}, {'Username': 'indiranagar_gossip', 'No_of_posts': '300 posts', 'No_of_followers': '8,900 followers', 'No_of_following': '20 following', 'Name': 'Indiranagar Spy', 'Type_of_page': 'Personal Blog', 'Bio': 'Not just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy'}, {'Username': 'ig_arbin07', 'No_of_posts': '50 posts', 'No_of_followers': '33 followers', 'No_of_following': '30 following', 'Name': 'aarbinnn', 'Type_of_page': 'Gamer', 'Bio': '@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'}, {'Username': '7iiuliiu', 'No_of_posts': '1 post', 'No_of_followers': '44 followers', 'No_of_following': '166 following', 'Name': '︎𝐄︎ ♡︎.', 'Type_of_page': 'Unknown', 'Bio': ''}, {'Username': 'katiasales2220', 'No_of_posts': '107 posts', 'No_of_followers': '219 followers', 'No_of_following': '1,4 ...

# %%
# Save parsed data into a JSON file
with open ("parsed_data", "w") as file:
    json.dump(all_chunks,file,  indent = 4)
#parsed_data = json.dumps(all_chunks, indent = 4)
print("Data has been Parsed Successfully!")
# Out:
# Data has been Parsed Successfully!
