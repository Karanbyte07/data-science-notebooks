# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#i want data with imdb greater than 7
df = df[df["IMDb"] > 7]

# %%
df
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2

# %%
#i want to write this data into updated csv but in this case it will give index to protect the data
df.to_csv("data_updated.csv")

# %%
#if i dont't want the index 
df.to_csv("data_updated.csv", index = False)

# %%
#read json file
df = pd.read_json("my-json.json")
df
# Out:
#    id     name                                     address
# 0   1    Alice      {'city': 'Delhi', 'zipcode': '243546'}
# 1   2      Bob     {'city': 'Mumbai', 'zipcode': '400001'}
# 2   3  Charlie      {'city': 'Noida', 'zipcode': '201301'}
# 3   4    Diana  {'city': 'Bangalore', 'zipcode': '560001'}
# 4   5    Ethan    {'city': 'Kolkata', 'zipcode': '700001'}

# %%
data = [
  {
    "id": 1,
    "name": "Alice",
    "address": {
      "city": "Delhi",
      "zipcode": "243546"
    }
  },
  {
    "id": 2,
    "name": "Bob",
    "address": {
      "city": "Mumbai",
      "zipcode": "400001"
    }
  }
]

# %%
#if i want to separate the data in address like city and zipcode with colm
df1 = pd.json_normalize(data)

# %%
df1
# Out:
#    id   name address.city address.zipcode
# 0   1  Alice        Delhi          243546
# 1   2    Bob       Mumbai          400001
